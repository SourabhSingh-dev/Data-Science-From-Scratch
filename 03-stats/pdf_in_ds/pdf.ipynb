# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
sns.kdeplot(data=df, x = 'sepal_length' , hue = 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.kdeplot(data=df,x = 'sepal_width',hue = "species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.kdeplot(data = df, x = 'petal_length' , hue = 'species')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.kdeplot(data= df , x = 'petal_width', hue = 'species')
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
sns.kdeplot(data = df, x = 'petal_width', hue = 'species')
sns.ecdfplot(data = df, x = 'petal_width' , hue = 'species')
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
sns.jointplot(data = df, x = 'petal_length', y = 'petal_width', kind='kde',fill=True, cbar = True)

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
sns.kdeplot(titanic['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
x = (titanic["Age"] - titanic['Age'].mean())/titanic['Age'].std()
sns.kdeplot(x)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
print(x.std())
x.mean()
# Out:
# 1.0
# np.float64(2.338621049070358e-16)

# %%
max_age = titanic["Age"].mean() + 3*titanic['Age'].std()
min_age = titanic["Age"].mean() - 3*titanic['Age'].std()

# %%
max_age
# Out:
# np.float64(73.27860964406094)

# %%
titanic[((titanic['Age'] < max_age) |( titanic['Age'] > min_age))]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Outlier 
titanic[((titanic['Age'] > max_age) |( titanic['Age'] < min_age))]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 630  male  80.0      0      0   27042  30.000   A23        S
# 851  male  74.0      0      0  347060   7.775   NaN        S
